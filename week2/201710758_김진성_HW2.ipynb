# %% [markdown]
# HW2 Image Disply
#
# Name : 김진성
#
# Student Number : 201710758

# %%
import numpy as np
from scipy.misc import imread, imresize
import matplotlib.pyplot as plt

# %%
img = imread("images.jpeg")
img_tinted = img*[1,0.8,0.8]

plt.subplot(1,2,1)
plt.imshow(img)

plt.subplot(1,2,2)
plt.imshow(np.uint8(img_tinted))

plt.show()
# Out:
# /Users/kimjinsung/opt/anaconda3/envs/digital_signal_processing/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
