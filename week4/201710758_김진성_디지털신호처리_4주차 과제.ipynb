# %% [markdown]
# # 디지털 신호 처리 4주차 과제
# ## 201710758 휴먼지능정보공학과 김진성

# %%
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot
import numpy as np

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ## 1100Hz Square Signal이며, 초당 10000 frame을 가집니다.

# %%
signal = thinkdsp.SquareSignal(1100)
duration = signal.period*3
segment = signal.make_wave(duration,framerate = 10000)
segment.plot()

# %% [markdown]
# ## aliase된부분들이 많이 보입니다.
# ### 1100, 2200, 3300 ~ 이 부분에만 있어야지 하모니를 이루는데, 다른 부분에 folding되면서 들어가 버려서, 하모니를 이루지 못합니다.

# %%
spectrum = wave.make_spectrum()
spectrum.plot()

# %% [markdown]
# ## 소리또한 들어봤을때, 듣기 거슬리는 하모니를 이루지 못하는 소리가 들립니다.

# %%
wave = signal.make_wave(duration=0.5, framerate=10000)
wave.apodize()
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
